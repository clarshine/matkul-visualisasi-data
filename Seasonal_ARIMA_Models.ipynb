# %% [markdown]
# <a href="https://colab.research.google.com/github/clarshine/matkul-visualisasi-data/blob/main/Seasonal_ARIMA_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (10, 5)
plt.style.use('fivethirtyeight')

# %%
milk_production = pd.read_csv('milk_production.csv', index_col='date', parse_dates=True)
milk_production = milk_production.asfreq('MS')
milk_production.head()
# Out:
#             pounds_per_cow
# date
# 1962-01-01           589.0
# 1962-02-01           561.0
# 1962-03-01           640.0
# 1962-04-01           656.0
# 1962-05-01           727.0

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform additive decomposition
decomp = seasonal_decompose(milk_production['pounds_per_cow'], period=12)

# Plot decomposition
decomp.plot();
plt.tight_layout();

# %%
water = pd.read_csv('water.csv', index_col='date', parse_dates=True)
water = water.asfreq('MS')
water.head()
# Out:
#             water_consumers
# date
# 1983-01-01            24963
# 1983-02-01            27380
# 1983-03-01            32588
# 1983-04-01            25511
# 1983-05-01            32313

# %%
water.plot();

# %%
from statsmodels.graphics.tsaplots import plot_acf

# Create figure and subplot
fig, ax1 = plt.subplots()

# Plot the ACF on ax1
plot_acf(water['water_consumers'], lags=25, zero=False, ax=ax1);

# %%
# Subtract the rolling mean
water_2 = water - water.rolling(15).mean()

# Drop the NaN values
water_2 = water_2.dropna()

# Create figure and subplots
fig, ax1 = plt.subplots()

# Plot the ACF
plot_acf(water_2['water_consumers'], lags=25, zero=False, ax=ax1);

# %%
df1 = pd.read_csv('df1.csv', index_col=0, parse_dates=True)
df2 = pd.read_csv('df2.csv', index_col=0, parse_dates=True)
df3 = pd.read_csv('df3.csv', index_col=0, parse_dates=True)

# %%
df1 = df1.asfreq('d')
df2 = df2.asfreq('d')
df3 = df3.asfreq('d')

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Create a SARIMAX model
model = SARIMAX(df1, order=(1, 0, 0), seasonal_order=(1, 1, 0, 7))

# Fit the model
results = model.fit()

# Print the results summary
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 Y   No. Observations:                   90
# Model:             SARIMAX(1, 0, 0)x(1, 1, 0, 7)   Log Likelihood                -556.243
# Date:                           Sun, 29 Jun 2025   AIC                           1118.486
# Time:                                   02:12:08   BIC                           1125.742
# Sample:                               01-01-2013   HQIC                          1121.401
#                                     - 03-31-2013
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1032      0.103      1.002      0.316      -0.099       0.305
# ar.S.L7        0.2781      0.104      2.665      0.008       0.074       0.483
# sigma2      3.858e+04   7224.679      5.340      0.000    2.44e+04    5.27e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.69
# Prob(Q):                              0.97   Prob(JB):                         0.43
# Heteroskedasticity (H):               1.35   Skew:                            -0.15
# Prob(H) (two-sided):                  0.43   Kurtosis:                         2.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Create a SARIMAX model
model = SARIMAX(df2, order=(2, 1, 1), seasonal_order=(1, 0, 0, 4))

# Fit the model
results = model.fit()

# Print the results summary
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  Y   No. Observations:                   80
# Model:             SARIMAX(2, 1, 1)x(1, 0, [], 4)   Log Likelihood                -560.340
# Date:                            Sun, 29 Jun 2025   AIC                           1130.679
# Time:                                    02:12:10   BIC                           1142.526
# Sample:                                01-01-2013   HQIC                          1135.426
#                                      - 03-21-2013
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2701      0.162      1.672      0.095      -0.047       0.587
# ar.L2          0.5015      0.110      4.560      0.000       0.286       0.717
# ma.L1         -0.4271      0.178     -2.401      0.016      -0.776      -0.078
# ar.S.L4        0.1075      0.127      0.847      0.397      -0.141       0.356
# sigma2       8.45e+04   1.63e+04      5.178      0.000    5.25e+04    1.16e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.95
# Prob(Q):                              1.00   Prob(JB):                         0.62
# Heteroskedasticity (H):               0.60   Skew:                            -0.07
# Prob(H) (two-sided):                  0.20   Kurtosis:                         2.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
aus_employment = pd.read_csv('aus_employment.csv', index_col='date', parse_dates=True)
aus_employment = aus_employment.asfreq('MS')
aus_employment.head()
# Out:
#             people_employed
# date
# 1978-01-01           5985.7
# 1978-02-01           6040.6
# 1978-03-01           6054.2
# 1978-04-01           6038.3
# 1978-05-01           6031.3

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# Take the first and seasonal differences and drop NaNs
aus_employment_diff = aus_employment.diff().diff(12).dropna()

# Create the figure
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))

# Plot the ACF on ax1
plot_acf(aus_employment_diff, lags=11, zero=False, ax=ax1);

# Plot the PACF on ax2
plot_pacf(aus_employment_diff, lags=11, zero=False, ax=ax2);
plt.tight_layout();

# %%
# Make list of lags
lags = [12, 24, 36, 48, 60]

# Create the figure
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))

# Plot the ACF on ax1
plot_acf(aus_employment_diff, lags=lags, zero=False, ax=ax1);

# Plot the PACF on ax2
plot_pacf(aus_employment_diff, lags=lags, zero=False, ax=ax2);
plt.tight_layout();

# %%
wisconsin_test = pd.read_csv('wisconsin_test.csv', index_col='date', parse_dates=True)
wisconsin_test = wisconsin_test.asfreq('MS')
dates = wisconsin_test.index
wisconsin_test.head()
# Out:
#             number_in_employment
# date
# 1973-10-01                 374.5
# 1973-11-01                 380.2
# 1973-12-01                 384.6
# 1974-01-01                 360.6
# 1974-02-01                 354.4

# %%
model = SARIMAX(wisconsin_test, order=(3, 1, 2), trend='c',
                enforce_stationarity=True, enforce_invertibility=True)

arima_results = model.fit()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model = SARIMAX(wisconsin_test, order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), trend='c',
                enforce_stationarity=True, enforce_invertibility=True)

sarima_results = model.fit()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
arima_results.specification
# Out:
# {'seasonal_periods': 0,
#  'measurement_error': False,
#  'time_varying_regression': False,
#  'simple_differencing': False,
#  'enforce_stationarity': True,
#  'enforce_invertibility': True,
#  'hamilton_representation': False,
#  'concentrate_scale': False,
#  'trend_offset': 1,
#  'order': (3, 1, 2),
#  'seasonal_order': (0, 0, 0, 0),
#  'k_diff': 1,
#  'k_seasonal_diff': 0,
#  'k_ar': 3,
#  'k_ma': 2,
#  'k_seasonal_ar': 0,
#  'k_seasonal_ma': 0,
#  'k_ar_params': 3,
#  'k_ma_params': 2,
#  'trend': 'c',
#  'k_trend': 1,
#  'k_exog': 0,
#  'mle_regression': False,
#  'state_regression': False}

# %%
sarima_results.specification
# Out:
# {'seasonal_periods': 12,
#  'measurement_error': False,
#  'time_varying_regression': False,
#  'simple_differencing': False,
#  'enforce_stationarity': True,
#  'enforce_invertibility': True,
#  'hamilton_representation': False,
#  'concentrate_scale': False,
#  'trend_offset': 1,
#  'order': (0, 1, 1),
#  'seasonal_order': (1, 1, 1, 12),
#  'k_diff': 1,
#  'k_seasonal_diff': 1,
#  'k_ar': 0,
#  'k_ma': 1,
#  'k_seasonal_ar': 12,
#  'k_seasonal_ma': 12,
#  'k_ar_params': 0,
#  'k_ma_params': 1,
#  'trend': 'c',
#  'k_trend': 1,
#  'k_exog': 0,
#  'mle_regression': False,
#  'state_regression': False}

# %%
# Create ARIMA mean forecast
arima_pred = arima_results.get_forecast(25)
arima_mean = arima_pred.predicted_mean

# Create SARIMA mean forecast
sarima_pred = sarima_results.get_forecast(25)
sarima_mean = sarima_pred.predicted_mean

# Plot mean ARIMA and SARIMA predictions and observed
plt.plot(dates, sarima_mean, label='SARIMA');
plt.plot(dates, arima_mean, label='ARIMA');
plt.plot(wisconsin_test, label='observed');
plt.legend();

# %%
# !pip install numpy==1.23.5
# !pip install pmdarima==1.8.5

import pmdarima as pm

# Create auto_arima model
model1 = pm.auto_arima(df1,
                      seasonal=True, m=7,
                      d=0, D=1,
                      max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

# Print model summary
print(model1.summary())
# Out:
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)
# Requirement already satisfied: pmdarima==1.8.5 in /usr/local/lib/python3.11/dist-packages (1.8.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (1.5.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (3.0.12)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (1.15.3)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (0.14.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (2.4.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.11/dist-packages (from pmdarima==1.8.5) (75.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima==1.8.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima==1.8.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pmdarima==1.8.5) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->pmdarima==1.8.5) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima==1.8.5) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima==1.8.5) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima==1.8.5) (1.17.0)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[7] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,0)(0,1,0)[7] intercept   : AIC=1124.433, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[7] intercept   : AIC=1120.434, Time=0.14 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,1)(0,1,1)[7] intercept   : AIC=1122.218, Time=0.09 sec
#  ARIMA(0,0,0)(0,1,0)[7]             : AIC=1122.596, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[7] intercept   : AIC=1125.048, Time=0.02 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,0,0)(2,1,0)[7] intercept   : AIC=1119.909, Time=0.25 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,0,0)(2,1,1)[7] intercept   : AIC=1121.791, Time=0.25 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,0,0)(1,1,1)[7] intercept   : AIC=1120.954, Time=0.21 sec
#  ARIMA(0,0,0)(2,1,0)[7] intercept   : AIC=1119.066, Time=0.19 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,0)(1,1,0)[7] intercept   : AIC=1119.294, Time=0.10 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,0)(2,1,1)[7] intercept   : AIC=1120.813, Time=0.21 sec
#  ARIMA(0,0,0)(1,1,1)[7] intercept   : AIC=1120.054, Time=0.12 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,1)(2,1,0)[7] intercept   : AIC=1119.937, Time=0.15 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,0,1)(2,1,0)[7] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,0)(2,1,0)[7]             : AIC=1117.139, Time=0.06 sec
#  ARIMA(0,0,0)(1,1,0)[7]             : AIC=1117.350, Time=0.03 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,0)(2,1,1)[7]             : AIC=1118.863, Time=0.17 sec
#  ARIMA(0,0,0)(1,1,1)[7]             : AIC=1118.127, Time=0.09 sec
#  ARIMA(1,0,0)(2,1,0)[7]             : AIC=1117.973, Time=0.10 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,1)(2,1,0)[7]             : AIC=1117.986, Time=0.11 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,0,1)(2,1,0)[7]             : AIC=1119.973, Time=0.38 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[7]
# Total fit time: 3.628 seconds
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:                       y   No. Observations:                   90
# Model:             SARIMAX(2, 1, 0, 7)   Log Likelihood                -555.569
# Date:                 Sun, 29 Jun 2025   AIC                           1117.139
# Time:                         02:12:46   BIC                           1124.395
# Sample:                              0   HQIC                          1120.054
#                                   - 90
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L7        0.2343      0.110      2.137      0.033       0.019       0.449
# ar.S.L14       0.1709      0.122      1.396      0.163      -0.069       0.411
# sigma2      3.791e+04   6875.994      5.514      0.000    2.44e+04    5.14e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.13   Jarque-Bera (JB):                 1.86
# Prob(Q):                              0.29   Prob(JB):                         0.39
# Heteroskedasticity (H):               1.38   Skew:                            -0.24
# Prob(H) (two-sided):                  0.40   Kurtosis:                         2.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Create model
model2 = pm.auto_arima(df2,
                       seasonal=False,
                       d=1,
                       trend='c',
                      max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

# Print model summary
print(model2.summary())
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1131.956, Time=0.53 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1153.963, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1155.355, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1155.747, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1153.963, Time=0.01 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1136.103, Time=1.05 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1130.992, Time=0.53 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1149.020, Time=0.85 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1132.526, Time=0.78 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1130.992, Time=1.48 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0] intercept
# Total fit time: 5.407 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   80
# Model:               SARIMAX(2, 1, 1)   Log Likelihood                -560.496
# Date:                Sun, 29 Jun 2025   AIC                           1130.992
# Time:                        02:12:58   BIC                           1142.840
# Sample:                             0   HQIC                          1135.739
#                                  - 80
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -9.5411     20.071     -0.475      0.635     -48.879      29.797
# ar.L1          0.2744      0.148      1.849      0.064      -0.016       0.565
# ar.L2          0.5383      0.098      5.503      0.000       0.347       0.730
# ma.L1         -0.4587      0.159     -2.886      0.004      -0.770      -0.147
# sigma2      8.558e+04   1.65e+04      5.197      0.000    5.33e+04    1.18e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.85
# Prob(Q):                              0.91   Prob(JB):                         0.66
# Heteroskedasticity (H):               0.60   Skew:                            -0.09
# Prob(H) (two-sided):                  0.20   Kurtosis:                         2.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Create model for SARIMAX(p,1,q)(P,1,Q)7
model3 = pm.auto_arima(df3,
                      seasonal=True, m=7,
                      d=1, D=1,
                      start_p=1, start_q=1,
                      max_p=1, max_q=1,
                      max_P=1, max_Q=1,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

# Print model summary
print(model3.summary())
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,1,1)[7]             : AIC=inf, Time=0.52 sec
#  ARIMA(0,1,0)(0,1,0)[7]             : AIC=1593.897, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[7]             : AIC=1583.263, Time=0.13 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(0,1,1)[7]             : AIC=inf, Time=0.24 sec
#  ARIMA(1,1,0)(0,1,0)[7]             : AIC=1593.659, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,1)[7]             : AIC=inf, Time=0.18 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(0,1,1)[7]             : AIC=inf, Time=0.15 sec
#  ARIMA(0,1,0)(1,1,0)[7]             : AIC=1581.972, Time=0.02 sec
#  ARIMA(0,1,0)(1,1,1)[7]             : AIC=inf, Time=0.12 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(0,1,1)[7]             : AIC=1575.886, Time=0.07 sec
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(0,1,1)[7]             : AIC=inf, Time=0.31 sec
#  ARIMA(0,1,0)(0,1,1)[7] intercept   : AIC=1577.811, Time=0.12 sec
#
# Best model:  ARIMA(0,1,0)(0,1,1)[7]
# Total fit time: 1.888 seconds
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  100
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 7)   Log Likelihood                -785.943
# Date:                             Sun, 29 Jun 2025   AIC                           1575.886
# Time:                                     02:13:07   BIC                           1580.930
# Sample:                                          0   HQIC                          1577.922
#                                              - 100
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L7       -0.6497      0.087     -7.434      0.000      -0.821      -0.478
# sigma2      1.521e+06   2.69e+05      5.648      0.000    9.93e+05    2.05e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.12   Jarque-Bera (JB):                 7.29
# Prob(Q):                              0.08   Prob(JB):                         0.03
# Heteroskedasticity (H):               1.06   Skew:                             0.66
# Prob(H) (two-sided):                  0.86   Kurtosis:                         2.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
import joblib

# Set model name
filename='candy_model.pkl'

# Pickle it
joblib.dump(model1, filename)

# Load the model back in
loaded_model = joblib.load(filename)

# Update the model
# loaded_model.update(df)

# %%
co2 = pd.read_csv('co2.csv', index_col='date', parse_dates=True)
co2 = co2.asfreq('MS')
co2.head()
# Out:
#             CO2_ppm
# date
# 1958-03-01   315.71
# 1958-04-01   317.45
# 1958-05-01   317.50
# 1958-06-01   317.10
# 1958-07-01   315.86

# %%
# Create model object
model = SARIMAX(co2, order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), trend='c')

# Fit model
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            CO2_ppm   No. Observations:                  727
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood                -179.718
# Date:                            Sun, 29 Jun 2025   AIC                            369.437
# Time:                                    02:14:27   BIC                            392.291
# Sample:                                03-01-1958   HQIC                           378.263
#                                      - 09-01-2018
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0017      0.001      2.805      0.005       0.001       0.003
# ar.L1          0.2414      0.078      3.077      0.002       0.088       0.395
# ma.L1         -0.6081      0.065     -9.302      0.000      -0.736      -0.480
# ma.S.L12      -0.8820      0.019    -45.505      0.000      -0.920      -0.844
# sigma2         0.0944      0.005     20.751      0.000       0.085       0.103
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 6.19
# Prob(Q):                              0.78   Prob(JB):                         0.05
# Heteroskedasticity (H):               1.13   Skew:                             0.00
# Prob(H) (two-sided):                  0.33   Kurtosis:                         3.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Plot common diagnostics
results.plot_diagnostics(figsize=(20, 15));
plt.tight_layout();

# %%
# Create forecast object
forecast_object = results.get_forecast(136)

# Extract predicted mean attribute
mean = forecast_object.predicted_mean

# Calculate the confidence intervals
conf_int = forecast_object.conf_int()

# Extract the forecast dates
dates = mean.index

plt.figure()

# Plot past CO2 levels
plt.plot(co2.index, co2, label='past');

# Plot the prediction means as line
plt.plot(dates, mean, label='predicted');

# Shade between the confidence intervals
plt.fill_between(dates, conf_int.loc[:, 'lower CO2_ppm'],
                 conf_int.loc[:, 'upper CO2_ppm'], alpha=0.4);

# Plot legend
plt.legend();
plt.savefig('co2_predicted.png')

# %%
# Print last predicted mean
print(mean.iloc[-1])

# Print last confidence interval
print(conf_int.iloc[-1])
# Out:
# 438.1948454400886
# lower CO2_ppm    432.112446
# upper CO2_ppm    444.277245
# Name: 2030-01-01 00:00:00, dtype: float64
